# %%
# !python Image2Image.py --cuda --batchSize=2 --loadSize 256 --dataset "extracolor" --num_joint_samples 417 --factorGAN 1 --experiment_name "real"
# Out:
# Namespace(L2=0.0, batchSize=2, beta1=0.5, cuda=True, dataset='extracolor', disc_iter=2, epoch_iter=5000, epochs=40, eval=False, eval_model='G', experiment_name='real', factorGAN=1, generator_channels=32, lipschitz_p=1, lipschitz_q=1, loadSize=256, lr=0.0001, num_joint_samples=417, nz=50, objective='JSD', out_path='out', seed=1337, use_real_dep_disc=1, workers=1)
# Random Seed:  1337
# dataset [AlignedDataset] was created
# START TRAINING! Writing logs to out/Image2Image_extracolor/real/logs
# 100%|███████████████████████████████████████| 5000/5000 [20:42<00:00,  4.02it/s]
# EPOCH FINISHED
# Saving generator at out/Image2Image_extracolor/real/G_0
# 100%|███████████████████████████████████████| 5000/5000 [20:46<00:00,  4.01it/s]
# EPOCH FINISHED
# Saving generator at out/Image2Image_extracolor/real/G_1
# 100%|███████████████████████████████████████| 5000/5000 [20:55<00:00,  3.98it/s]
# EPOCH FINISHED
# Saving generator at out/Image2Image_extracolor/real/G_2
# ...

# %%
# !python Image2Image.py --cuda --batchSize=2 --loadSize 256 --dataset "extracolor" --num_joint_samples 417 --factorGAN 1 --experiment_name "real" --eval
# Out:
# Namespace(L2=0.0, batchSize=2, beta1=0.5, cuda=True, dataset='extracolor', disc_iter=2, epoch_iter=5000, epochs=40, eval=True, eval_model='G', experiment_name='real', factorGAN=1, generator_channels=32, lipschitz_p=1, lipschitz_q=1, loadSize=256, lr=0.0001, num_joint_samples=417, nz=50, objective='JSD', out_path='out', seed=1337, use_real_dep_disc=1, workers=1)
# Random Seed:  1337
# dataset [AlignedDataset] was created

# %%
# !python Image2Image.py --cuda --batchSize=2 --loadSize 256 --epoch_iter 366 --epochs 200 --dataset "fg" --num_joint_samples 366 --factorGAN 1 --experiment_name "jul"
# Out:
# Namespace(L2=0.0, batchSize=2, beta1=0.5, cuda=True, dataset='fg', disc_iter=2, epoch_iter=366, epochs=200, eval=False, eval_model='G', experiment_name='jul', factorGAN=1, generator_channels=32, lipschitz_p=1, lipschitz_q=1, loadSize=256, lr=0.0001, num_joint_samples=366, nz=50, objective='JSD', out_path='out', seed=1337, use_real_dep_disc=1, workers=1)
# Random Seed:  1337
# dataset [AlignedDataset] was created
# START TRAINING! Writing logs to out/Image2Image_fg/jul/logs
# ...
# 100%|█████████████████████████████████████████| 366/366 [09:28<00:00,  1.55s/it]
# EPOCH FINISHED
# Saving generator at out/Image2Image_fg/jul/G_0
# 100%|█████████████████████████████████████████| 366/366 [06:24<00:00,  1.05s/it]
# EPOCH FINISHED
# Saving generator at out/Image2Image_fg/jul/G_1
# 100%|█████████████████████████████████████████| 366/366 [01:53<00:00,  3.22it/s]
# EPOCH FINISHED
# Saving generator at out/Image2Image_fg/jul/G_2
# ...
